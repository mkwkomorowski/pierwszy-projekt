# %% [markdown]
# # Wczytywanie i zapisywanie plików w Pandas

# %%
import pandas as pd

# %% [markdown]
# ## 1. Wczytywanie plików CSV – podstawy

# %%
# Zakładamy, że plik `sample.csv` znajduje się w katalogu roboczym
# domyślny separator to przecinek
df = pd.read_csv('sales_records.csv')
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# ### 1.1 Różne separatory
# Popularne separatory:
# - `,` (przecinek) – domyślny w `read_csv`
# - `;` (średnik) – często w plikach generowanych z Excela w polskich systemach
# - `\t` (tabulacja) – tzw. TSV
# - `|` (pipe)
#
# Użycie parametru `sep` pozwala określić separator.

# %%
df_semicolon = pd.read_csv('sample_semicolon.csv', sep=';')
# df_tab = pd.read_csv('sample.tsv', sep='\t')
# df_pipe = pd.read_csv('sample_pipe.txt', sep='|')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_semicolon = pd.read_csv('sample_semicolon.csv', sep=';')
#       2 # df_tab = pd.read_csv('sample.tsv', sep='\t')
#       3 # df_pipe = pd.read_csv('sample_pipe.txt', sep='|')
#
# ...

# %% [markdown]
# ### 1.2 Inne przydatne parametry
# | Parametr | Opis |
# |----------|------|
# | `encoding` | Ustawia stronę kodową, np. `'latin1'`, `'cp1250'`, `'utf-8-sig'` |
# | `header` | Numer wiersza zawierającego nagłówki lub `None` jeśli brak |
# | `names` | Lista nazw kolumn, przydatna gdy `header=None` |
# | `skiprows` | Pomija podaną liczbę wierszy na początku pliku |
# | `nrows` | Odczytuje tylko podaną liczbę wierszy |
# | `usecols` | Wybiera kolumny po nazwach lub indeksach |
# | `dtype` | Wymusza konkretne typy kolumn |
# | `parse_dates` | Konwertuje kolumny do typu `datetime` |

# %%
df = pd.read_csv('sales_records.csv', header=None)
df
# Out:
#                                     0                      1   \
# 0                               Region                Country
# 1                Australia and Oceania                 Tuvalu
# 2    Central America and the Caribbean                Grenada
# 3                               Europe                 Russia
# 4                   Sub-Saharan Africa  Sao Tome and Principe
# ..                                 ...                    ...
# 96                  Sub-Saharan Africa                   Mali
# 97                                Asia               Malaysia
# 98                  Sub-Saharan Africa           Sierra Leone
# 99                       North America                 Mexico
# 100                 Sub-Saharan Africa             Mozambique
#
#                   2              3               4           5          6   \
# 0          Item Type  Sales Channel  Order Priority  Order Date   Order ID
# ...

# %% [markdown]
# ### 1.3 Wczytywanie dużych plików – iterator
# Parametr `chunksize` zwraca iterator, który wczytuje plik partiami (chunkami) określonej wielkości.

# %%
iter_df = pd.read_csv('sales_records.csv', chunksize=10)
for chunk in iter_df:
    # tutaj moglibyśmy np. agregować dane
    display(chunk)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %% [markdown]
# ## 2. Wczytywanie plików Excel

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
# Podgląd dostępnych arkuszy (Pamiętaj o dodaniu pliku `sales_records.xlsx` do katalogu roboczego.)
xls = pd.ExcelFile('sales_records.xlsx')
xls.sheet_names
# Out:
# ['sales_records']

# %%
df_sheet = pd.read_excel('sales_records.xlsx')

# %%
df_sheet
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# Wczytanie konkretnego arkusza (po nazwie lub indeksie)
df_sheet = pd.read_excel('sales_records.xlsx', sheet_name='sales_records')
df_first = pd.read_excel('sales_records.xlsx', sheet_name=0)
df_first
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# Wczytanie wszystkich arkuszy naraz (słownik DataFrame'ów)
dfs = pd.read_excel('sales_records (1).xlsx', sheet_name=None)
list(dfs.keys())
# Out:
# ['sales_records', 'Sales_2']

# %%
dfs
# Out:
# {'sales_records':                                Region                Country        Item Type  \
#  0               Australia and Oceania                 Tuvalu        Baby Food
#  1   Central America and the Caribbean                Grenada           Cereal
#  2                              Europe                 Russia  Office Supplies
#  3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
#  4                  Sub-Saharan Africa                 Rwanda  Office Supplies
#  ..                                ...                    ...              ...
#  95                 Sub-Saharan Africa                   Mali          Clothes
#  96                               Asia               Malaysia           Fruits
#  97                 Sub-Saharan Africa           Sierra Leone       Vegetables
#  98                      North America                 Mexico    Personal Care
#  99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
dfs['Sales_2']
# Out:
#    a
# 0  1
# 1  2
# 2  3
# 3  4

# %%
type(dfs)
# Out:
# dict

# %% [markdown]
# Parametry `read_excel` są dość podobne do `read_csv`, np.

# %%
pd.read_excel('sales_records.xlsx', usecols=['Order ID', 'Total Revenue'])
# Out:
#      Order ID Total Revenue
# 0   669165933    2533654.00
# 1   963881480     576782.80
# 2   341417157    1158502.59
# 3   514321792      75591.66
# 4   115456712    3296425.02
# ..        ...           ...
# 95  512878119      97040.64
# 96  810711038      58471.11
# 97  728815257     228779.10
# 98  559427106     471336.91
# 99  665095412    3586605.09
#
# [100 rows x 2 columns]

# %%
pd.read_excel('sales_records.xlsx', skiprows=5, header=None)
# Out:
#                        0                      1                2        3  4   \
# 0      Sub-Saharan Africa                 Rwanda  Office Supplies  Offline  L
# 1   Australia and Oceania        Solomon Islands        Baby Food   Online  C
# 2      Sub-Saharan Africa                 Angola        Household  Offline  M
# 3      Sub-Saharan Africa           Burkina Faso       Vegetables   Online  H
# 4      Sub-Saharan Africa  Republic of the Congo    Personal Care  Offline  M
# ..                    ...                    ...              ...      ... ..
# 91     Sub-Saharan Africa                   Mali          Clothes   Online  M
# 92                   Asia               Malaysia           Fruits  Offline  L
# 93     Sub-Saharan Africa           Sierra Leone       Vegetables  Offline  C
# 94          North America                 Mexico    Personal Care  Offline  M
# 95     Sub-Saharan Africa             Mozambique        Household  Offline  L
#
# ...

# %% [markdown]
# ## 3. Zapisywanie danych do plików

# %%
df = pd.read_csv('sales_records.csv')
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# CSV bez indeksu (domyślny separator = ',')
df.to_csv('wyjscie.csv', index=False)

# %%
df.to_csv('wyjscie.csv')

# %%
df.to_csv('wyjscie_polski.csv', sep=';', decimal=',', index=False)

# %% [markdown]
# ### 3.1 Parametry zapisu CSV
# - `sep` – separator
# - `decimal` – symbol dziesiętny
# - `encoding` – strona kodowa (np. `utf-8-sig` do poprawnego otwarcia w Excelu)
# - `float_format` – formatowanie liczb zmiennoprzecinkowych, np. `'%.2f'`
# - `date_format` – format dat, np. `'%Y-%m-%d'`

# %% [markdown]
# ## 4. Ćwiczenie praktyczne
# 1. Pobierz dowolny zbiór danych w formacie CSV z portalu [data.gov.pl](https://dane.gov.pl/).
# 2. Wczytaj plik przy użyciu `pd.read_csv`, zwracając uwagę na poprawny separator oraz kodowanie.
# 3. Wyświetl podstawowe informacje o zbiorze (`head()`).
# 4. Zapisz przefiltrowane dane do pliku `wynik.csv` z separatorem `;` i kodowaniem `utf-8-sig`.
# 5. To samo, co wcześniej, tylko dla dowolnego pliku XLSX z portalu data.gov.pl - wczytanie za pomocą `pd.read_excel` - zwróć uwagę na istniejące arkusze w pliku.

# %%
df = pd.read_csv('Imiona_nadane_dzieciom_w_Polsce_w_I_połowie_2025_r._-_imię_drugie.csv', sep=';')
df
# Out:
#       IMIĘ_2 PŁEĆ  LICZBA
# 0      MARIA    K    2186
# 1       ANNA    K    1402
# 2      ZOFIA    K     823
# 3     HELENA    K     427
# 4      ŁUCJA    K     423
# ..       ...  ...     ...
# 486   VIKTOR    M       2
# 487   WALTER    M       2
# 488  WINCENT    M       2
# 489     ZEUS    M       2
# 490  ZYGFRYD    M       2
#
# [491 rows x 3 columns]

# %%
df.head()
# Out:
#    IMIĘ_2 PŁEĆ  LICZBA
# 0   MARIA    K    2186
# 1    ANNA    K    1402
# 2   ZOFIA    K     823
# 3  HELENA    K     427
# 4   ŁUCJA    K     423

# %%
df[df['PŁEĆ'] == "M"].to_csv('wynik.csv', sep=';', encoding='utf-8-sig', index=False)

# %% [markdown]
# 1. Pobierz dowolny zbiór danych w formacie CSV z portalu [data.gov.pl](https://dane.gov.pl/).
# 2. Wczytaj plik przy użyciu `pd.read_csv`, zwracając uwagę na poprawny separator oraz kodowanie.
# 3. Wyświetl podstawowe informacje o zbiorze (`head()`).
# 4. Zapisz przefiltrowane dane do pliku `wynik.csv` z separatorem `;` i kodowaniem `utf-8-sig`.

# %%
df =pd.read_excel('5_-_Wykaz_imion_żeńskich_nadanych_dzieciom_urodzonym_w_2024_r._wg_pola_imię_drugie__statystyka_ogólna_dla_całej_Polski.xlsx', sheet_name='Arkusz1')

df.head()
# Out:
#   IMIĘ_DRUGIE     PŁEĆ  LICZBA_WYSTĄPIEŃ
# 0       MARIA  KOBIETA              4840
# 1        ANNA  KOBIETA              3233
# 2       ZOFIA  KOBIETA              1798
# 3      HELENA  KOBIETA              1060
# 4    WIKTORIA  KOBIETA              1009

# %%
df[df['LICZBA_WYSTĄPIEŃ'] >=500].to_excel('wyjście_excel.xlsx', index=False)
