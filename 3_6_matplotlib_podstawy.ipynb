# %% [markdown]
# # 📊 Temat 6: Podstawy Matplotlib
#
# W tym notatniku poznasz podstawy tworzenia wykresów za pomocą biblioteki Matplotlib. Matplotlib jest jedną z najpopularniejszych bibliotek do wizualizacji danych w Pythonie, pozwalającą na tworzenie statycznych, interaktywnych i zaawansowanych wykresów.

# %% [markdown]
# ## 📦 Importowanie bibliotek

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## 🏗️ Podstawowa struktura Matplotlib
#
# Najważniejsze elementy w Matplotlib:
# - **Figure**: główny kontener na wykresy
# - **Axes**: właściwe miejsce rysowania wykresu
# - **Axis**: osie X i Y

# %% [markdown]
# ## 📈 Tworzenie prostego wykresu

# %%
# Tworzenie danych
x = np.linspace(0, 10, 100)  # 100 punktów od 0 do 10
y = np.sin(x)                # funkcja sinus

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title('Wykres funkcji sinus')
plt.xlabel('Oś X')
plt.ylabel('Oś Y')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  # rozmiar: szerokość x wysokość w calach
plt.plot(x, y)
plt.title('Wykres funkcji sinus')
plt.xlabel('Oś X')
plt.ylabel('Oś Y')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🎨 Style i kolory linii

# %%
plt.figure(figsize=(12, 6))

# Różne style linii
plt.plot(x, np.sin(x), 'r-', label='sin(x) - linia ciągła czerwona')
plt.plot(x, np.cos(x), 'b-.', label='cos(x) - linia przerywana niebieska')
plt.plot(x, np.sin(x+np.pi/4), 'g:', label='sin(x+π/4) - linia kropkowana zielona')
plt.plot(x, np.sin(x-np.pi/4), 'm*-.', label='sin(x-π/4) - linia z markerami magenta')

# Dodajemy legendę
plt.legend()
plt.title('Różne style linii')
plt.grid(True)

plt.show()

# %% [markdown]
# Oznaczenia stylu:
# - Kolor: `r` (red), `g` (green), `b` (blue), `c` (cyan), `m` (magenta), `y` (yellow), `k` (black), `w` (white)
# - Styl linii: `-` (solid), `--` (dashed), `-.` (dash-dot), `:` (dotted)
# - Markery: `.` (point), `o` (circle), `s` (square), `^` (triangle), `*` (star)

# %% [markdown]
# ## 📊 Różne typy wykresów

# %% [markdown]
# ### Wykres punktowy (Scatter)

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.scatter(x, y)
plt.show()

# %%
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

# %%
colors
# Out:
# array([0.57268006, 0.89006281, 0.52323094, 0.75953208, 0.98167994,
#        0.91664175, 0.24153713, 0.84308682, 0.1926023 , 0.24571986,
#        0.36432644, 0.86113639, 0.27706735, 0.36773932, 0.23423434,
#        0.09219796, 0.91223653, 0.90590427, 0.04263621, 0.9198961 ,
#        0.34876973, 0.24186751, 0.09647816, 0.45953306, 0.46114143,
#        0.99752657, 0.87280031, 0.42633931, 0.98626157, 0.8506595 ,
#        0.82959431, 0.56710029, 0.5366837 , 0.07651118, 0.2657111 ,
#        0.08219037, 0.83330673, 0.06199997, 0.19218529, 0.95035737,
#        0.76054012, 0.136219  , 0.40655704, 0.29946659, 0.89429466,
#        0.5737817 , 0.8461959 , 0.24576489, 0.63768355, 0.84789437])

# %%
sizes
# Out:
# array([985.55739379, 330.660435  , 870.17514337, 178.25349004,
#        107.49587865, 425.60884112, 492.61552314, 597.94686894,
#        893.24876752, 520.37987754,  59.46889854, 148.71112724,
#        148.79109084, 869.51236823, 606.61856601, 794.36427792,
#        580.77147126, 898.45695398, 955.010576  , 137.8357393 ,
#        132.16943986, 775.44979886, 794.7629599 , 579.4236989 ,
#        923.86856538,  55.90179662, 888.48376633, 288.88972458,
#        949.48110997, 514.08487651, 588.0265976 , 442.56822028,
#        588.03178373, 485.97511413, 962.73104147, 538.84010794,
#        182.87349614, 230.27390519, 443.86729912, 255.01822603,
#        677.44978897, 286.69156916, 807.18985617, 552.97480399,
#        491.4345076 ,  94.99703707, 379.10708495, 116.49756365,
#        732.85625072, 190.48826346])

# %%
plt.figure(figsize=(10, 6))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar()  # dodanie paska kolorów
plt.title('Wykres punktowy (Scatter)')
plt.show()

# %% [markdown]
# ### Wykres słupkowy (Bar)

# %%
plt.figure(figsize=(10, 6))
kategorie = ['A', 'B', 'C', 'D', 'E']
wartosci = [3, 7, 2, 9, 4]

plt.bar(kategorie, wartosci)
plt.title('Wykres słupkowy')
plt.xlabel('Kategorie')
plt.ylabel('Wartości')
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(10, 6))
dane = np.random.randn(1000)  # dane z rozkładu normalnego

plt.hist(dane, bins=30)
plt.title('Histogram')
plt.xlabel('Wartości')
plt.ylabel('Częstość')
plt.grid(True, alpha=0.5)
plt.show()

# %% [markdown]
# ## 📑 Wiele wykresów w jednym oknie (subplots)

# %%
# Tworzenie siatki 2x2 wykresów
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

# Wykres w pozycji (0,0)
axes[0, 0].plot(x, np.sin(x), 'b-')
axes[0, 0].set_title('Sinus')
axes[0, 0].grid(True)

# Wykres w pozycji (0,1)
axes[0, 1].plot(x, np.cos(x), 'r-')
axes[0, 1].set_title('Cosinus')
axes[0, 1].grid(True)

# Wykres w pozycji (1,0)
axes[1, 0].scatter(np.random.rand(50), np.random.rand(50), c='green')
axes[1, 0].set_title('Wykres punktowy')

# Wykres w pozycji (1,1)
axes[1, 1].hist(np.random.randn(500), bins=20, color='orange')
axes[1, 1].set_title('Histogram')

plt.show()

# %% [markdown]
# ## 🖼️ Zapisywanie wykresów do plików

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, np.sin(x), 'g-', label='sin(x)')
plt.plot(x, np.cos(x), 'b--', label='cos(x)')
plt.title('Wykres do zapisania')
plt.legend()
plt.grid(True)

# Zapisywanie do różnych formatów
plt.savefig('wykres.png', dpi=300)  # format PNG z wysoką rozdzielczością
plt.show()

# %% [markdown]
# ## 🧪 Zadania praktyczne
#
# **Zadanie 1**: Stwórz wykres funkcji kwadratowej f(x) = x² w przedziale [-5, 5].

# %%
# Zadanie 1
# Twój kod tutaj
x = np.linspace(-5, 5, 100)
y = x ** 2

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title('Wykres funkcji kwadratowej y = x**2')
plt.xlabel('Oś X')
plt.ylabel('Oś Y')
plt.xlim(-5, 5)
plt.xticks(np.arange(-5, 6, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# **Zadanie 2**: Stwórz wykres słupkowy przedstawiający dane:
# - Kategorie: 'Jabłka', 'Banany', 'Pomarańcze', 'Gruszki', 'Winogrona'
# - Ilości: [25, 40, 30, 23, 37]

# %%
# Zadanie 2
# Twój kod tutaj
items = ['Jabłka', 'Banany', 'Pomarańcze', 'Gruszki', 'Winogrona']
quantities = [25, 40, 30, 23, 37]

plt.figure(figsize=(10, 6))
plt.bar(items, quantities)
plt.title('Wykres słupkowy')
plt.xlabel('Kategorie')
plt.ylabel('Wartości')
plt.show()

# %% [markdown]
# **Zadanie 3**: Stwórz wykres z dwiema osiami Y, pokazujący temperaturę (°C) i wilgotność (%) w ciągu tygodnia.

# %%
# Zadanie 3
# Twój kod tutaj
x = ['monday', 'tuesday', 'wednesday', 'thursday',
    'friday', 'saturday', 'sunday']
temp = np.random.normal(loc=20, scale=2, size=7)
humidity = np.random.normal(loc=60, scale=10, size=7)

fig, ax1 = plt.subplots()

# Oś lewa
ax1.plot(x, temp, color='tab:blue')
ax1.set_xlabel('dni tygodnia')
ax1.set_ylabel('temp [°C]', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Oś prawa (druga pionowa)
ax2 = ax1.twinx()
ax2.plot(x, humidity, color='tab:red')
ax2.set_ylabel('humidity [% relative]', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.show()

# %% [markdown]
# **Zadanie 4**: Stwórz wykres 3D przedstawiający funkcję z = sin(x) * cos(y) w przedziałach x, y ∈ [-3, 3].

# %%
# Zadanie 4
# Twój kod tutaj
# siatka punktów
x = y = np.linspace(-3, 3, 200)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

# wykres 3D
fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z = sin(x) * cos(y)')
ax.set_title('z = sin(x) * cos(y), x,y ∈ [-3,3]')

fig.colorbar(surf, shrink=0.6, aspect=10, label='z')
plt.show()

# %%
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
